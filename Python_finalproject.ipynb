# %% [markdown]
# # Python for Genomic Data Analysis
#
# ## Final project:
#
# ## Management and visualization of genetic sequences from whole genomes
#
# The objectives of this project are:
#
# * 1. Create a function to extract genes of interest from one or more genomes.
# * 2. Create a function to filter the sequences to the desired bp length.
# * 3. Align the retrived sequences with mafft.
# * 4. Generate a gene tree and visualize it.
#
# The gene of interest is the ATPase alpha subunit. It is important in the process of detoxification performed by insects against toxic substances of the plants they consume. Here we will analyze eighteen genomes of milkweed longhorn beetles and other insect orders including butterflies and true bugs.

# %% [markdown]
# ## Installing required software
#
# BioPython is already installed so let's confirm we are in the bioinfo environment:

# %%
# !echo $CONDA_DEFAULT_ENV
# Out:
# bioinfo

# %% [markdown]
# Load libraries and install iqtree and ete.

# %%
from Bio import SeqIO, AlignIO
from Bio.SeqRecord import SeqRecord
from ete3 import Tree, TreeStyle, NodeStyle

# conda install -c bioconda iqtree ete3

# %% [markdown]
# See content of current directory.

# %%
# !ls -lh #$WD
# Out:
# total 6568
# -rw-r--r--@  1 nayeligutierrez  staff    30K Feb  1 11:51 1.assembly_supernova.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    31K Mar  3 15:52 2.assembly_optimization.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   203K Jan 28 14:53 3.repeatmasker.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    12K Jan 13 18:33 4.busco_install(unsuccesfull1).ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    18K Jan 13 18:33 5.busco_install(unsuccesfull2).ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    23K Apr 28 19:58 6.busco_install(succesfull).ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    15K Jan 14 20:49 7.illumina_qc.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    49K Feb 24 14:21 8.assembly_illumina.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    60K Apr 30 19:26 9.1.phylogeny.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    34K Apr 30 19:26 9.2.Maker_Braker.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   158K Apr 28 18:28 9.3.Blast.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    14K May  3 18:22 9.4InterProtScan.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   5.6K Mar 25 00:12 9.5Positive_selection.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    16K May  6 12:45 ABCB1.fasta
# -rw-r--r--   1 nayeligutierrez  staff   1.0K May  5 20:55 ABCB1.mafft.FastTree.nwk
# -rw-r--r--@  1 nayeligutierrez  staff    42K May  5 20:53 ABCB1.mafft.fasta
# -rw-r--r--@  1 nayeligutierrez  staff   209K May  9 13:53 ATPase_subunit_alpha.fasta
# -rw-r--r--@  1 nayeligutierrez  staff   209K May  6 12:07 ATPases.fasta
# -rw-r--r--@  1 nayeligutierrez  staff   5.6K May  5 20:44 ATPases.mafft.FastTree.nwk
# -rw-r--r--@  1 nayeligutierrez  staff   376K May  5 20:37 ATPases.mafft.fasta
# -rw-r--r--   1 nayeligutierrez  staff     0B May  5 07:10 ATPases2.mafft.fasta
# -rw-r--r--@  1 nayeligutierrez  staff     0B May  5 18:43 ATPases_filtered_for_tree.FastTree.nwk
# -rw-r--r--@  1 nayeligutierrez  staff   150K May  5 20:41 ATPases_filtered_for_tree.fasta
# -rw-r--r--   1 nayeligutierrez  staff   5.6K May  5 19:02 ATPases_filtered_for_tree.mafft.FastTree.nwk
# -rw-r--r--@  1 nayeligutierrez  staff   366K May  5 20:42 ATPases_filtered_for_tree.mafft.fasta
# drwxr-xr-x@  4 nayeligutierrez  staff   128B May  3 19:31 Atpases_Tetraopes_only
# -rw-r--r--@  1 nayeligutierrez  staff   7.1K Apr 30 19:40 Chapter1.MehodsOverview.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   5.2K Apr 12 20:05 Detecting_Structural_Variations.ipynb
# -rw-r--r--   1 nayeligutierrez  staff    99K May  8 21:05 Final_project_python-Copy1.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    99K May  9 13:49 Final_project_python.ipynb
# -rw-r--r--   1 nayeligutierrez  staff    88K May  5 20:59 Final_project_python_backup.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    49K Apr 28 19:23 Gutierrez_CG2pipeline.ipynb
# drwxr-xr-x@ 29 nayeligutierrez  staff   928B May  5 21:02 Img
# -rw-r--r--@  1 nayeligutierrez  staff   104K May  5 19:03 PythonFinalProject_gene_in_whole_genomes-currentv copy.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    16K May  5 20:38 PythonFinalProject_gene_in_whole_genomes-currentv.ipynb
# drwxr-xr-x@  4 nayeligutierrez  staff   128B Apr 26 18:49 PythonFinalProject_genes_in_whole_genomes
# -rw-r--r--@  1 nayeligutierrez  staff    22K Apr 22 16:00 PythonFinalProject_genes_in_whole_genomes_backup.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    31K Apr 28 19:21 PythonFinalProject_genes_in_whole_genomes_backup2.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    34K May  5 17:56 PythonFinalProject_genes_in_whole_genomes_backup3.ipynb
# -rw-r--r--   1 nayeligutierrez  staff    39K May  9 16:53 Python_finalproject.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   8.7K Mar 21 20:55 Resources_GenomicAnalysis.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   7.1K May  4 22:09 Taxon_sampling_genomes.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   1.8K Jan 27 11:25 Untitled.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff   581B Mar 21 12:35 Untitled1.ipynb
# -rw-r--r--   1 nayeligutierrez  staff   105K May  5 20:22 Untitled2.ipynb
# -rw-r--r--@  1 nayeligutierrez  staff    14K Apr 26 19:23 abcb.fasta
# -rw-r--r--@  1 nayeligutierrez  staff    33K Apr 26 19:26 abcb.mafft.fasta
# -rw-r--r--@  1 nayeligutierrez  staff   3.0K Feb 26 19:44 bashrc_backup_26022021.ipynb
# drwxr-xr-x@ 20 nayeligutierrez  staff   640B May  4 23:01 functionally_annotated_genomes
# -rw-r--r--@  1 nayeligutierrez  staff   306B May  9 13:53 genomes_files.list
# -rw-r--r--@  1 nayeligutierrez  staff     0B May  5 13:22 oatp.fasta
# -rw-r--r--@  1 nayeligutierrez  staff   119K May  5 12:48 oatp.mafft.fasta
# -rw-r--r--@  1 nayeligutierrez  staff    18K Apr 26 20:45 oatp_file.fasta
# -rw-r--r--@  1 nayeligutierrez  staff    37K May  6 13:43 organic anion transporter family member 5.fasta
# -rw-r--r--   1 nayeligutierrez  staff    37K May  6 13:50 organic_anion_transporter_family_member_5.fasta
# -rw-r--r--@  1 nayeligutierrez  staff     0B Apr 26 20:45 other_file.fasta

# %% [markdown]
# Looks like we are in the right directory, now let's create a variable with the directory where the genome files are located:

# %%
genomes_dir = 'functionally_annotated_genomes/'
# !ls -l $genomes_dir
# Out:
# total 929936
# -rw-r--r--@ 1 nayeligutierrez  staff  42564506 Apr 28 19:47 Aglabripennis.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  26454908 Apr 29 18:33 Bmori.fasta
# -rw-r--r--  1 nayeligutierrez  staff  18140062 May  4 22:59 Clectularius.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  22515159 May  3 23:17 Dplexippus.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  23212105 May  3 21:19 Ofasciatus.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  18863127 Mar 19 22:58 Rlineaticollis1.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  27303125 Mar 27 19:21 Tannulatus1.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  23329748 Mar 12 16:07 Tannulatus2.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  52399286 Apr 28 20:56 Tcastaneum.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  24256983 Mar 12 23:04 Tdiscoideus1.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  30193583 Mar 17 23:54 Tdiscoideus2.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  23528473 Mar 14 20:39 Tfemoratus1.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  36986249 Mar 15 17:44 Tfemoratus2.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  31126854 Mar 16 23:43 Tpilosus1.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  23217171 Mar 17 17:08 Tpilosus2.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  16136467 Mar 16 17:11 Tskillmani1.fasta
# -rw-r--r--@ 1 nayeligutierrez  staff  29834235 Mar 20 21:52 Ttetrophthalmus.fasta

# %% [markdown]
# ## 1. Extract gene secuences from genome files
#
# We have 18 genome annotation files from where I want to extract only the sequences that correspond to ATPase subunit alpha. To avoid doing it one by one, let's create a function that uses as argument the name of the gene we are looking for and the directory where the genomes are located. The function will:
#
# **a)** Extract sequences that match the desired gene.
#
# **b)** Append sequences to a file.
#
# **c)** Rename sequences to indicate what species they correspond to.

# %%
def genefind(gene_name, genomes_dir, split_name=True, ignore_case=True):
  """
  Looks for genes one or several genomes. The sequences found are renamed using the file name where they were 
  found and are appended to a file. 
  param gene_name is name of the gene of interest.
  param genomes_dir is directory where the genome(s) are.
  param split_name looks for the name of the gene with its letters arranged in all order combinations.
  param ignore_case makes gene_name lowercase.
  """
  # Split the gene name because it can be in a different order (default)
  if split_name:
    terms = gene_name.split() # "ATPase subunit Alpha" --> ["ATPase","subunit", "Alpha"]
  else:
    terms = [gene_name]
  # Make all terms lowercase if ignoring case (default)
  if ignore_case:
    terms = [term.lower() for term in terms] # --> ["atpase","subunit", "alpha"]
  
  # Define variables
  genomes_files = 'genomes_files.list'
  # !ls $genomes_dir > $genomes_files
  # !cat $genomes_files

  gene_name_file = gene_name.replace(" ", "_") + ".fasta"

  # Clear the file so that it starts empty
  with open(gene_name_file, 'w') as f:
    pass

  with open(genomes_files, 'r') as f:
    for filename in f:
      # Remove space between names
      filename = filename.strip()
      print("\n" + filename)
      seqrecs = SeqIO.parse(genomes_dir + filename, 'fasta') 

      # Go over each record in this file
      for rec in seqrecs:
        # Create variable for the description of each record
        desc = rec.description
        if ignore_case:
          desc = desc.lower()
        # Extract sequences that match the gene
        if all([term in desc for term in terms]):
          # Append sequences to a file where all sequences will be stored
          print(rec.description)
          with open(gene_name_file, 'a') as g:   
            # Rename sequences to indicate what species they correspond to
            rec.id = filename.replace('.fasta', '_') + rec.id
            rec.description = ''
            g.write(rec.format('fasta'))
  # Count the number of sequences found                      
  number_sequences = !grep -c "^>" $gene_name_file
  # Redefine data type of the variable (from string to integer)
  number_sequences = int(number_sequences[0])
  print(f"\n{number_sequences} sequences matching \"{gene_name}\" have been retrieved in the file \"{gene_name_file}\"")

# %% [markdown]
# Let's use genefind() to look for the sequences that match the name of the gene ATPase subunit alpha. The function is designed to find sequences that match that name even when the words are not in the right order. For example, it will find sequences named "ATPase subunit alpha" as well as those named "ATPase alpha subunit" and "subunit alpha ATPase", etc.:

# %%
genefind("ATPase subunit alpha", "functionally_annotated_genomes/")
# Out:
# Aglabripennis.fasta
# Bmori.fasta
# Clectularius.fasta
# Dplexippus.fasta
# Ofasciatus.fasta
# Rlineaticollis1.fasta
# Tannulatus1.fasta
# Tannulatus2.fasta
# Tcastaneum.fasta
# Tdiscoideus1.fasta
# Tdiscoideus2.fasta
# Tfemoratus1.fasta
# Tfemoratus2.fasta
# Tpilosus1.fasta
# Tpilosus2.fasta
# Tskillmani1.fasta
# Ttetrophthalmus.fasta
#
# Aglabripennis.fasta
# lcl|NW_019416354.1_cds_XP_018565491.1_5686 [gene=LOC108906661] [db_xref=GeneID:108906661] [protein=sodium/potassium-transporting ATPase subunit alpha] [protein_id=XP_018565491.1] [location=complement(join(259262..259373,259425..259539,260985..261173,261524..261769,261830..262102,262161..262422,264862..265245,265508..265731,265783..266028,267310..267546,268306..268435,269663..269830,270039..270211,297296..297445,341693..341813))] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562049.1_6847 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X1] [protein_id=XP_018562049.1] [location=join(996763..996792,1049362..1049442,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1066236..1066330,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562050.1_6848 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X2] [protein_id=XP_018562050.1] [location=join(996763..996792,1049362..1049442,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1071249..1071343,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562051.1_6849 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X3] [protein_id=XP_018562051.1] [location=join(996763..996792,1049362..1049442,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1072155..1072249,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562054.1_6850 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X6] [protein_id=XP_018562054.1] [location=join(1013415..1013435,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1066236..1066330,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562052.1_6851 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X4] [protein_id=XP_018562052.1] [location=join(1045217..1045225,1049362..1049442,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1066236..1066330,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562053.1_6852 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X5] [protein_id=XP_018562053.1] [location=join(1045217..1045225,1049362..1049442,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1071249..1071343,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562055.1_6853 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X7] [protein_id=XP_018562055.1] [location=join(1045217..1045225,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1066236..1066330,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562056.1_6854 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X8] [protein_id=XP_018562056.1] [location=join(1045217..1045225,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1071249..1071343,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019416398.1_cds_XP_018562057.1_6855 [gene=LOC108904109] [db_xref=GeneID:108904109] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X9] [protein_id=XP_018562057.1] [location=join(1045217..1045225,1051712..1051840,1053820..1054066,1054715..1056430,1061484..1061785,1072155..1072249,1073846..1074020,1074694..1074926,1075924..1076044)] [gbkey=CDS]
# lcl|NW_019417389.1_cds_XP_023312013.1_17588 [gene=LOC108911543] [db_xref=GeneID:108911543] [protein=LOW QUALITY PROTEIN: sodium/potassium-transporting ATPase subunit alpha-4-like] [exception=unclassified translation discrepancy] [protein_id=XP_023312013.1] [location=join(22293..22489,28198..28439,28494..28658,28713..28952,29006..29338,29398..29675,29798..30101,30252..30486,30542..30720,30821..31137,31140..31380,31434..31852)] [gbkey=CDS]
#
# Bmori.fasta
#
# Clectularius.fasta
# CLEC006776-RA Sodium/potassium-transporting ATPase subunit alpha|GO:0006813 GO:0005524 GO:0016021 GO:0008556
#
# Dplexippus.fasta
# DPOGS214640-TA sodium/potassium-transporting ATPase subunit alpha isoform X1|GO:0016887 GO:0006813 GO:0005524 GO:0016021 GO:0008556
# DPOGS213623-TA sodium/potassium-transporting ATPase subunit alpha-like|GO:0016887 GO:0005524 GO:0016021
# DPOGS211186-TA sodium/potassium-transporting ATPase subunit alpha-like|GO:0016887 GO:0006813 GO:0005524 GO:0016021 GO:0008556
#
# Ofasciatus.fasta
# lcl|KK854243.1_cds_PTY13626.1_4739 [locus_tag=OFAS_OFAS025028] [db_xref=I5KNAL:OFAS025028] [protein=Na+/K+ ATPase alpha subunit 1B] [partial=5',3'] [protein_id=PTY13626.1] [location=join(<95851..96054,98471..98584,98670..98922,99824..100045,101839..102084,104890..104984,106861..107053,108746..108994,112673..112811,18913606..113748,114592..114848,120895..121071,122164..122294,125269..>125370)] [gbkey=CDS]
# lcl|KK854243.1_cds_PTY13634.1_4747 [locus_tag=OFAS_OFAS006682] [db_xref=I5KNAL:OFAS006682] [protein=Na+/K+ ATPase alpha subunit 1C-RB] [partial=3'] [protein_id=PTY13634.1] [location=complement(join(<275606..275780,281694..281788,305350..305606,305689..305831,307004..307142,309756..309948,311267..311399,312654..312765,316322..316567,318123..318342,322571..322684,325369..325572,326669..326791,340849..340941,341474..341716))] [gbkey=CDS]
# lcl|KK854243.1_cds_PTY13635.1_4748 [locus_tag=OFAS_OFAS006682] [db_xref=I5KNAL:OFAS006682] [protein=Na+/K+ ATPase alpha subunit 1C-RA] [partial=3'] [protein_id=PTY13635.1] [location=complement(join(<275606..275780,286641..286735,305350..305606,305689..305831,307004..307142,309756..309948,311267..311399,312654..312765,316322..316567,318123..318342,322571..322684,325369..325572,326669..326791,340849..340941,341474..341716))] [gbkey=CDS]
# lcl|KK854249.1_cds_PTY13707.1_4820 [locus_tag=OFAS_OFAS005636] [db_xref=I5KNAL:OFAS005636] [protein=putative Na+/K+ ATPase alpha subunit 1 -putative] [protein_id=PTY13707.1] [location=join(308971..309144,314378..314581,316147..316260,316341..316593,316682..316903,322224..322442,322600..322711,324817..324949,330617..330809,334387..334635,337028..337166,337451..337593,337679..337935,340715..340809,343191..343437)] [gbkey=CDS]
# lcl|KK854697.1_cds_PTY17974.1_9087 [locus_tag=OFAS_OFAS025195] [db_xref=I5KNAL:OFAS025195] [protein=Na+/K+ ATPase alpha-subunit 1A] [protein_id=PTY17974.1] [location=complement(join(192606..192726,194824..194925,197116..197246,198100..198274,198978..199072,199661..199917,200030..200037,202858..202996,203918..204166,204972..205164,207088..207220,207728..207839,209153..209398,210452..210673,213038..213290,213373..213486,220810..220935,237736..237747))] [gbkey=CDS]
# lcl|KK854787.1_cds_PTY18716.1_9829 [locus_tag=OFAS_OFAS025086] [db_xref=I5KNAL:OFAS025086] [protein=Na+/K+ ATPase alpha-subunit 2] [protein_id=PTY18716.1] [location=164206..167316] [gbkey=CDS]
# lcl|KK860120.1_cds_PTY28023.1_19136 [locus_tag=OFAS_OFAS019006] [db_xref=I5KNAL:OFAS019006] [protein=Na+/K+ ATPase alpha-subunit 1A] [partial=5',3'] [protein_id=PTY28023.1] [location=complement(<5295..>5498)] [gbkey=CDS]
# lcl|KK861086.1_cds_PTY28150.1_19263 [locus_tag=OFAS_OFAS025178] [db_xref=I5KNAL:OFAS025178] [protein=Na+/K+ ATPase alpha subunit 1C] [protein_id=PTY28150.1] [location=complement(join(3421..3424,5972..6073,9210..>9316))] [gbkey=CDS]
# lcl|KK864120.1_cds_PTY28389.1_19502 [locus_tag=OFAS_OFAS025097] [db_xref=I5KNAL:OFAS025097] [protein=Na+ K+ ATPase alpha-subunit 1B] [partial=5'] [protein_id=PTY28389.1] [location=complement(232..>351)] [gbkey=CDS]
# lcl|JHQO01322203.1_cds_PTX75966.1_19640 [locus_tag=OFAS_OFAS025147] [db_xref=I5KNAL:OFAS025147] [protein=Na+/K+ ATPase alpha subunit 1C] [partial=5',3'] [protein_id=PTX75966.1] [location=complement(<640..>892)] [gbkey=CDS]
#
# Rlineaticollis1.fasta
# 2043046.g3 Sodium/potassium-transporting ATPase subunit alpha
# 2200260.g20 Na+/K+ ATPase alpha subunit
# 2718861.g13 Sodium/potassium-transporting ATPase subunit alpha
# 3116583.g40 sodium/potassium-transporting ATPase subunit alpha
# 6644992.g15 sodium/potassium-transporting ATPase subunit alpha isoform X6
# 8445445.g35 sodium/potassium-transporting ATPase subunit alpha isoform X9
# 9280121.g26 sodium/potassium-transporting ATPase subunit alpha isoform X3
# 12447157.g16 sodium/potassium-transporting ATPase subunit alpha
# 15155240.g8 sodium/potassium-transporting ATPase subunit alpha isoform X4
# 16086664.g19 sodium/potassium-transporting ATPase subunit alpha-like
# 17167391.g29 Sodium/potassium-transporting ATPase subunit alpha
# 17373146.g32 sodium/potassium ATPase alpha subunit
# 20169353.g84 Na+/K+ ATPase alpha subunit
# 20207899.g86 sodium/potassium-transporting ATPase subunit alpha
# 20254541.g134 sodium/potassium-transporting ATPase subunit alpha isoform X6
# 20254542.g135 sodium/potassium-transporting ATPase subunit alpha isoform X6
#
# Tannulatus1.fasta
# 2020233.g45 sodium/potassium-transporting ATPase subunit alpha-like
# 2465216.g23 sodium/potassium-transporting ATPase subunit alpha isoform X2
# 4949613.g52 sodium/potassium-transporting ATPase subunit alpha-like
# 5823139.g10 sodium/potassium-transporting ATPase subunit alpha-like
# 5824627.g6 sodium/potassium-transporting ATPase subunit alpha isoform X2
# 5839395.g68 sodium/potassium-transporting ATPase subunit alpha isoform X3
# 5852914.g76 sodium/potassium ATPase alpha subunit
#
# Tannulatus2.fasta
# 4368716.g59 sodium/potassium-transporting ATPase subunit alpha-like
# 5311409.g40 Na+/K+ ATPase alpha subunit
# 6313654.g17 sodium/potassium-transporting ATPase subunit alpha-like
# 6685367.g42 sodium/potassium-transporting ATPase subunit alpha-like
# 6685946.g8 sodium/potassium-transporting ATPase subunit alpha-like
# 6776066.g34 sodium/potassium-transporting ATPase subunit alpha-like
# 6816384.g133 sodium/potassium-transporting ATPase subunit alpha isoform X3
#
# Tcastaneum.fasta
# lcl|NC_007417.3_cds_XP_015840522.1_3417 [db_xref=GeneID:661036] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X2] [protein_id=XP_015840522.1] [location=complement(join(13236547..13236658,13236703..13237003,13237049..13237294,13237340..13237612,13237803..13238067,13238114..13238497,13238546..13238763,13238803..13239267,13239323..13239452,13239833..13240000,13240053..13240237,13240284..13240433,13240477..13240588))] [gbkey=CDS]
# lcl|NC_007417.3_cds_XP_008190275.2_3418 [db_xref=GeneID:661036] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X1] [protein_id=XP_008190275.2] [location=complement(join(13236547..13236658,13236703..13237003,13237049..13237294,13237340..13237612,13237803..13238067,13238114..13238497,13238546..13238763,13238803..13239279,13239323..13239452,13239833..13240000,13240053..13240237,13240284..13240433,13240477..13240588))] [gbkey=CDS]
# lcl|NC_007417.3_cds_XP_972369.1_3419 [db_xref=GeneID:661092] [protein=sodium/potassium-transporting ATPase subunit alpha] [protein_id=XP_972369.1] [location=join(13241059..13241182,13241598..13241747,13241898..13242070,13243902..13245290,13245342..13245600,13247325..13247597,13247644..13247889,13247937..13248125,13248173..13248287,13248340..13248451)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_015837163.1_15311 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X4] [protein_id=XP_015837163.1] [location=join(13170644..13170673,13184429..13184509,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13190040..13190134,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196417.1_15312 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X1] [protein_id=XP_008196417.1] [location=join(13170644..13170673,13184429..13184509,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13190562..13190656,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196418.1_15313 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X3] [protein_id=XP_008196418.1] [location=join(13170644..13170673,13184429..13184509,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13191367..13191461,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196419.1_15314 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X2] [protein_id=XP_008196419.1] [location=join(13170644..13170673,13184429..13184509,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13191914..13192008,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196422.1_15315 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X8] [protein_id=XP_008196422.1] [location=join(13170644..13170673,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13190562..13190656,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_015837164.1_15316 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X7] [protein_id=XP_015837164.1] [location=join(13173621..13173656,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13190562..13190656,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196420.1_15317 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X5] [protein_id=XP_008196420.1] [location=join(13183256..13183264,13184429..13184509,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13190562..13190656,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196421.1_15318 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X6] [protein_id=XP_008196421.1] [location=join(13183256..13183264,13184429..13184509,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13191367..13191461,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196423.1_15319 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X9] [protein_id=XP_008196423.1] [location=join(13183256..13183264,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13190562..13190656,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196424.1_15320 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X11] [protein_id=XP_008196424.1] [location=join(13183256..13183264,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13191367..13191461,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007422.5_cds_XP_008196425.1_15321 [db_xref=GeneID:663833] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X10] [protein_id=XP_008196425.1] [location=join(13183256..13183264,13185331..13185459,13185510..13185756,13186783..13188498,13189610..13189911,13191914..13192008,13193699..13193873,13193928..13194160,13194210..13194330)] [gbkey=CDS]
# lcl|NC_007423.3_cds_XP_971478.1_16258 [db_xref=GeneID:660125] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X2] [protein_id=XP_971478.1] [location=complement(join(5396272..5396687,5396736..5396951,5397003..5397248,5400262..5400717,5400765..5401068,5404969..5405987,5407034..5407269,5407320..5407450))] [gbkey=CDS]
# lcl|NC_007423.3_cds_XP_015837921.1_16259 [db_xref=GeneID:660125] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X1] [protein_id=XP_015837921.1] [location=complement(join(5396272..5396687,5396736..5397248,5400262..5400717,5400765..5401068,5404969..5405987,5407034..5407269,5407320..5407450))] [gbkey=CDS]
# lcl|NC_007423.3_cds_XP_015837922.1_16260 [db_xref=GeneID:660125] [protein=sodium/potassium-transporting ATPase subunit alpha isoform X3] [protein_id=XP_015837922.1] [location=complement(join(5396682..5396687,5396740..5397248,5400262..5400717,5400765..5401068,5404969..5405987,5407034..5407269,5407320..5407450))] [gbkey=CDS]
#
# Tdiscoideus1.fasta
# 1854031.g58 Na+/K+ ATPase alpha subunit
# 2086639.g45 sodium/potassium-transporting ATPase subunit alpha isoform X3
# 5565729.g65 sodium/potassium-transporting ATPase subunit alpha-like
# 6702885.g23 sodium/potassium-transporting ATPase subunit alpha-like
# 6709994.g48 sodium/potassium-transporting ATPase subunit alpha-like
# 6770603.g14 Na+/K+ ATPase alpha subunit
# 6795269.g101 sodium/potassium-transporting ATPase subunit alpha isoform X6
#
# Tdiscoideus2.fasta
# 2890578.g52 Na+/K+ ATPase alpha subunit
# 3689124.g70 sodium/potassium-transporting ATPase subunit alpha-like
# 3746555.g55 Na+/K+ ATPase alpha subunit
# 4198478.g3 sodium/potassium-transporting ATPase subunit alpha-like
# 2469352.g65 Na+/K+ ATPase alpha subunit
#
# Tfemoratus1.fasta
# 1654610.g24 sodium/potassium ATPase alpha subunit
# 2246706.g47 sodium/potassium ATPase alpha subunit
# 3077924.g10 Na+,K+ ATPase alpha-subunit 1
# 3178549.g18 sodium/potassium-transporting ATPase subunit alpha
# 9062756.g67 sodium/potassium-transporting ATPase subunit alpha-like
# 9193525.g41 sodium/potassium-transporting ATPase subunit alpha-like
# 9235822.g33 sodium/potassium-transporting ATPase subunit alpha isoform X3
# 9243440.g114 sodium/potassium-transporting ATPase subunit alpha
#
# Tfemoratus2.fasta
# 584367.g107 sodium/potassium-transporting ATPase subunit alpha isoform X4
# 1803787.g106 putative v-type proton atpase catalytic subunit a v-atpase subunit aec proton pump subunit alphav-atpase kda subunit
# 2406488.g35 sodium/potassium-transporting ATPase subunit alpha-like
# 3114834.g47 Na+/K+ ATPase alpha subunit
# 3648632.g46 Na+/K+ ATPase alpha subunit
# 4327769.g89 putative v-type proton atpase catalytic subunit a v-atpase subunit aec proton pump subunit alphav-atpase kda subunit
# 8610776.g97 sodium/potassium-transporting ATPase subunit alpha isoform X6
# 8651013.g277 sodium/potassium-transporting ATPase subunit alpha
#
# Tpilosus1.fasta
# 1280300.g52 sodium/potassium-transporting ATPase subunit alpha-like
# 2065760.g33 sodium/potassium-transporting ATPase subunit alpha
# 4271307.g61 Na+/K+ ATPase alpha subunit
# 5418222.g21 sodium/potassium-transporting ATPase subunit alpha-like
# 5479739.g69 Na+/K+ ATPase alpha subunit
# 5483190.g86 sodium/potassium-transporting ATPase subunit alpha-like
# 5494332.g64 Na+,K+ ATPase alpha-subunit 2
# 5497471.g120 Na+/K+ ATPase alpha subunit
#
# Tpilosus2.fasta
# 4168272.g56 sodium/potassium-transporting ATPase subunit alpha
# 4819112.g7 sodium/potassium-transporting ATPase subunit alpha isoform X2
# 7269390.g66 sodium/potassium-transporting ATPase subunit alpha isoform X3
# 7357420.g51 sodium/potassium-transporting ATPase subunit alpha-like
# 7466746.g9 sodium/potassium ATPase alpha subunit
#
# Tskillmani1.fasta
# 8091818.g1 Na+/K+ ATPase alpha subunit
# 11213243.g9 sodium/potassium-transporting ATPase subunit alpha-like
# 12903966.g5 sodium/potassium-transporting ATPase subunit alpha-like
# 13287441.g63 sodium/potassium-transporting ATPase subunit alpha-like
# 13290908.g54 sodium/potassium-transporting ATPase subunit alpha-like
# 13294620.g47 sodium/potassium-transporting ATPase subunit alpha isoform X9
# 13332957.g20 Na+/K+ ATPase alpha subunit
#
# Ttetrophthalmus.fasta
# maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1 sodium/potassium-transporting ATPase subunit alpha isoform X9
# maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1 sodium/potassium-transporting ATPase subunit alpha
# maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1 sodium/potassium-transporting ATPase subunit alpha-like
#
# 123 sequences matching "ATPase subunit alpha" have been retrieved in the file "ATPase_subunit_alpha.fasta"

# %% [markdown]
# Result: 123 sequences matching "ATPase subunit alpha" have been retrieved in the file "ATPase_subunit_alpha.fasta"

# %% [markdown]
# ## 2. Filter the sequences to a desired bp length

# %% [markdown]
# Using genefind(), 123 sequences were retrieved. The length of the sequences varies from 3460 to 50 bp. Some of the sequences are very short to be included in further steps of the pipeline. Before moving forward with sequence alignment, we will use the seqfilter() function to fliter sequences shorter than 1000 bp (the minimum length chosen is an arbitrary):

# %%
def seqfilter(fasta_file, min_length):
  """
  Filter sequences with a user-defined threshold and creates two files, one containing sequences that have 
  passed the threshold and one with sequences that did not. 
  param fasta_file is name of the file.
  param min_length is the number of bp of the threshold.
  """
  # Create fasta files where to storage sequences 
  long_seqs_file = fasta_file.replace("fasta", "filtered.fasta")
  short_seqs_file = fasta_file.replace("fasta", "shortseqs.fasta")
    
  # Define seqrecs using SeqIO
  seqrecs = SeqIO.parse(fasta_file, "fasta") 
    
  # Clear the files so that they start empty
  with open(long_seqs_file, 'w') as f:
    pass
  with open(short_seqs_file, 'w') as f:
    pass     
  
  # Go over each record in the file
  for rec in seqrecs:
    # If the record is longer than the min_length
    if len(rec) > min_length:
      # Append sequences to a file where all long sequences will be stored
      print(rec.description)
      with open(long_seqs_file, 'a') as g:   
        g.write(rec.format('fasta'))
    else:
      # Append sequences to a file where all short sequences will be stored
      print(rec.description)
      with open(short_seqs_file, 'a') as g:   
        g.write(rec.format('fasta'))
  # Count the number of sequences found           
  num_long_sequences = !grep -c "^>" $long_seqs_file
  # Redefine data type of the variable (from string to integer)
  num_long_sequences = int(num_long_sequences[0])
  print(f"\n{num_long_sequences} sequences passed the {min_length} bp threshold. They have been retrieved in the file \"{long_seqs_file}\"")

# %% [markdown]
# Let's use seqfilter() to filter the sequences in the "ATPase_subunit_alpha.fasta" file:

# %%
seqfilter("ATPase_subunit_alpha.fasta", 1000)
# Out:
# Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855
# Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588
# Clectularius_CLEC006776-RA
# Dplexippus_DPOGS214640-TA
# Dplexippus_DPOGS213623-TA
# Dplexippus_DPOGS211186-TA
# Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739
# Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747
# Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748
# Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820
# Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087
# Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829
# Ofasciatus_lcl|KK860120.1_cds_PTY28023.1_19136
# Ofasciatus_lcl|KK861086.1_cds_PTY28150.1_19263
# Ofasciatus_lcl|KK864120.1_cds_PTY28389.1_19502
# Ofasciatus_lcl|JHQO01322203.1_cds_PTX75966.1_19640
# Rlineaticollis1_2043046.g3
# Rlineaticollis1_2200260.g20
# Rlineaticollis1_2718861.g13
# Rlineaticollis1_3116583.g40
# Rlineaticollis1_6644992.g15
# Rlineaticollis1_8445445.g35
# Rlineaticollis1_9280121.g26
# Rlineaticollis1_12447157.g16
# Rlineaticollis1_15155240.g8
# Rlineaticollis1_16086664.g19
# Rlineaticollis1_17167391.g29
# Rlineaticollis1_17373146.g32
# Rlineaticollis1_20169353.g84
# Rlineaticollis1_20207899.g86
# Rlineaticollis1_20254541.g134
# Rlineaticollis1_20254542.g135
# Tannulatus1_2020233.g45
# Tannulatus1_2465216.g23
# Tannulatus1_4949613.g52
# Tannulatus1_5823139.g10
# Tannulatus1_5824627.g6
# Tannulatus1_5839395.g68
# Tannulatus1_5852914.g76
# Tannulatus2_4368716.g59
# Tannulatus2_5311409.g40
# Tannulatus2_6313654.g17
# Tannulatus2_6685367.g42
# Tannulatus2_6685946.g8
# Tannulatus2_6776066.g34
# Tannulatus2_6816384.g133
# Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417
# Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418
# Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419
# Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315
# Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321
# Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258
# Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259
# Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260
# Tdiscoideus1_1854031.g58
# Tdiscoideus1_2086639.g45
# Tdiscoideus1_5565729.g65
# Tdiscoideus1_6702885.g23
# Tdiscoideus1_6709994.g48
# Tdiscoideus1_6770603.g14
# Tdiscoideus1_6795269.g101
# Tdiscoideus2_2890578.g52
# Tdiscoideus2_3689124.g70
# Tdiscoideus2_3746555.g55
# Tdiscoideus2_4198478.g3
# Tdiscoideus2_2469352.g65
# Tfemoratus1_1654610.g24
# Tfemoratus1_2246706.g47
# Tfemoratus1_3077924.g10
# Tfemoratus1_3178549.g18
# Tfemoratus1_9062756.g67
# Tfemoratus1_9193525.g41
# Tfemoratus1_9235822.g33
# Tfemoratus1_9243440.g114
# Tfemoratus2_584367.g107
# Tfemoratus2_1803787.g106
# Tfemoratus2_2406488.g35
# Tfemoratus2_3114834.g47
# Tfemoratus2_3648632.g46
# Tfemoratus2_4327769.g89
# Tfemoratus2_8610776.g97
# Tfemoratus2_8651013.g277
# Tpilosus1_1280300.g52
# Tpilosus1_2065760.g33
# Tpilosus1_4271307.g61
# Tpilosus1_5418222.g21
# Tpilosus1_5479739.g69
# Tpilosus1_5483190.g86
# Tpilosus1_5494332.g64
# Tpilosus1_5497471.g120
# Tpilosus2_4168272.g56
# Tpilosus2_4819112.g7
# Tpilosus2_7269390.g66
# Tpilosus2_7357420.g51
# Tpilosus2_7466746.g9
# Tskillmani1_8091818.g1
# Tskillmani1_11213243.g9
# Tskillmani1_12903966.g5
# Tskillmani1_13287441.g63
# Tskillmani1_13290908.g54
# Tskillmani1_13294620.g47
# Tskillmani1_13332957.g20
# Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1
# Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1
# Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1
#
# 70 sequences passed the 1000 bp threshold. They have been retrieved in the file "ATPase_subunit_alpha.filtered.fasta"

# %% [markdown]
# Result: only 70 of the 123 sequences were longer than 1000 bp. Sequences of less than 1000 bp were stored in a different file in case they need to be inspected later.

# %% [markdown]
# ## 3. Align the sequences retrieved using mafft

# %% [markdown]
# Now that we have only sequences longer than 1000 bp, we'll proceed with aligning them.

# %%
# Create variable for aligned sequences
filtered_atpases_file = "ATPase_subunit_alpha.filtered.fasta"
# Create a file to storage aligned sequences
aligned_file = filtered_atpases_file.replace(".fasta", ".mafft.fasta")

# Use mafft to align the sequences
# !mafft $filtered_atpases_file > $aligned_file
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#
# There are 31 ambiguous characters.
#     1 / 70
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#    60 / 70
# done.
#
# Progressive alignment 1/2...
# STEP    55 / 69
# Reallocating..done. *alloclen = 7993
# STEP    69 / 69
# done.
#
# Making a distance matrix from msa..
#     0 / 70
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#    60 / 70
# done.
#
# Progressive alignment 2/2...
# STEP    54 / 69
# Reallocating..done. *alloclen = 7951
# STEP    69 / 69
# done.
#
# disttbfast (nuc) Version 7.475
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# ## 4. Generate a gene tree
#
# The next step is to use the aligned sequences to generate a gene tree. For this step we will assume that all recovered sequences are descendants of a common ancestor and we will use a maximum likelihood algorithm to obtain a gene tree.

# %%
# Use ModelFinderPlus (MFP) in IQTREE to determine the best-fit model:
# !iqtree -s $aligned_file -m MFP

# %% [markdown]
# What model best fitted our data?

# %%
# !cat ATPase_subunit_alpha.filtered.mafft.fasta.iqtree
# Out:
# IQ-TREE 2.1.2 COVID-edition built Mar 30 2021
#
# Input file name: ATPase_subunit_alpha.filtered.mafft.fasta
# Type of analysis: ModelFinder + tree reconstruction
# Random seed number: 427365
#
# REFERENCES
# ----------
#
# To cite IQ-TREE please use:
#
# Bui Quang Minh, Heiko A. Schmidt, Olga Chernomor, Dominik Schrempf,
# Michael D. Woodhams, Arndt von Haeseler, and Robert Lanfear (2020)
# IQ-TREE 2: New models and efficient methods for phylogenetic inference
# in the genomic era. Mol. Biol. Evol., in press.
# https://doi.org/10.1093/molbev/msaa015
#
# To cite ModelFinder please use:
#
# Subha Kalyaanamoorthy, Bui Quang Minh, Thomas KF Wong, Arndt von Haeseler,
# and Lars S Jermiin (2017) ModelFinder: Fast model selection for
# accurate phylogenetic estimates. Nature Methods, 14:587–589.
# https://doi.org/10.1038/nmeth.4285
#
# SEQUENCE ALIGNMENT
# ------------------
#
# Input data: 70 sequences with 4382 nucleotide sites
# Number of constant sites: 1583 (= 36.1251% of all sites)
# Number of invariant (constant or ambiguous constant) sites: 1583 (= 36.1251% of all sites)
# Number of parsimony informative sites: 2332
# Number of distinct site patterns: 3007
#
# ModelFinder
# -----------
#
# Best-fit model according to BIC: GTR+F+G4
#
# List of models sorted by BIC scores:
#
# Model                  LogL         AIC      w-AIC        AICc     w-AICc         BIC      w-BIC
# GTR+F+G4         -51152.501  102597.002 +    0.388  102607.137 +    0.405  103529.250 +    0.937
# GTR+F+I+G4       -51151.048  102596.096 +    0.611  102606.373 +    0.594  103534.729 +   0.0605
# TIM2+F+G4        -51166.842  102621.683 -  1.7e-06  102631.540 - 2.04e-06  103541.161 -  0.00243
# TIM2+F+I+G4      -51165.397  102620.793 - 2.65e-06  102630.789 - 2.96e-06  103546.656 - 0.000156
# GTR+F+R5         -51153.620  102613.239 - 0.000116  102624.385 - 7.29e-05  103590.184 - 5.49e-14
# GTR+F+R6         -51149.390  102608.780 -  0.00107  102620.224 - 0.000584  103598.496 - 8.61e-16
# GTR+F+R4         -51172.852  102647.704 -  3.8e-12  102658.556 - 2.77e-12  103611.878 - 1.07e-18
# TIM3+F+G4        -51203.369  102694.739 - 2.32e-22  102704.595 - 2.79e-22  103614.216 - 3.32e-19
# TIM3+F+I+G4      -51202.478  102694.956 - 2.08e-22  102704.952 - 2.33e-22  103620.819 - 1.22e-20
# TN+F+G4          -51215.436  102716.873 - 3.63e-27  102726.590 - 4.67e-27  103629.965 - 1.26e-22
# TIM+F+G4         -51213.220  102714.440 - 1.22e-26  102724.296 - 1.47e-26  103633.917 - 1.75e-23
# TN+F+I+G4        -51214.447  102716.893 - 3.59e-27  102726.749 - 4.31e-27  103636.371 - 5.14e-24
# TIM+F+I+G4       -51212.123  102714.246 - 1.35e-26  102724.241 - 1.51e-26  103640.109 - 7.92e-25
# TIM2e+G4         -51248.173  102778.346 - 1.62e-40  102787.790 -  2.4e-40  103678.668 - 3.36e-33
# TVM+F+G4         -51232.959  102755.917 - 1.21e-35  102765.912 - 1.35e-35  103681.780 - 7.08e-34
# TIM2e+I+G4       -51246.342  102776.684 - 3.73e-40  102786.264 - 5.14e-40  103683.391 - 3.17e-34
# SYM+G4           -51245.056  102776.112 - 4.96e-40  102785.829 - 6.39e-40  103689.204 - 1.73e-35
# TVM+F+I+G4       -51232.861  102757.722 - 4.89e-36  102767.857 -  5.1e-36  103689.970 - 1.18e-35
# TPM2u+F+G4       -51246.332  102778.664 - 1.39e-40  102788.381 - 1.78e-40  103691.756 - 4.83e-36
# TPM2+F+G4        -51246.332  102778.664 - 1.39e-40  102788.381 - 1.78e-40  103691.756 - 4.83e-36
# SYM+I+G4         -51243.111  102774.221 - 1.28e-39  102784.077 - 1.53e-39  103693.699 - 1.83e-36
# TPM2+F+I+G4      -51246.180  102780.361 - 5.93e-41  102790.217 - 7.12e-41  103699.838 - 8.49e-38
# TPM2u+F+I+G4     -51246.180  102780.361 - 5.93e-41  102790.217 - 7.12e-41  103699.838 - 8.49e-38
# GTR+F+R3         -51239.566  102777.132 - 2.98e-40  102787.695 - 2.51e-40  103728.536 - 4.98e-44
# TPM3+F+G4        -51282.682  102851.364 - 2.26e-56  102861.082 - 2.91e-56  103764.456 - 7.89e-52
# TPM3u+F+G4       -51282.682  102851.364 - 2.26e-56  102861.082 - 2.91e-56  103764.456 - 7.89e-52
# TPM3u+F+I+G4     -51282.884  102853.768 - 6.81e-57  102863.624 - 8.17e-57  103773.245 - 9.74e-54
# TPM3+F+I+G4      -51282.884  102853.768 - 6.81e-57  102863.624 - 8.17e-57  103773.245 - 9.74e-54
# HKY+F+G4         -51293.736  102871.472 - 9.74e-61  102881.053 - 1.34e-60  103778.179 - 8.27e-55
# K3Pu+F+G4        -51291.824  102869.649 - 2.42e-60  102879.367 - 3.12e-60  103782.741 - 8.45e-56
# TVMe+G4          -51297.011  102878.021 - 3.68e-62  102887.602 - 5.08e-62  103784.728 - 3.13e-56
# HKY+F+I+G4       -51293.777  102873.554 - 3.44e-61  102883.271 - 4.43e-61  103786.646 -  1.2e-56
# K3Pu+F+I+G4      -51291.885  102871.770 - 8.39e-61  102881.626 - 1.01e-60  103791.248 -  1.2e-57
# TVMe+I+G4        -51296.361  102878.721 -  2.6e-62  102888.439 - 3.34e-62  103791.813 - 9.05e-58
# TIMe+G4          -51338.382  102958.763 - 1.08e-79  102968.208 - 1.59e-79  103859.085 - 2.23e-72
# TNe+G4           -51343.542  102967.083 - 1.69e-81  102976.392 - 2.66e-81  103861.020 - 8.49e-73
# TIMe+I+G4        -51337.156  102958.312 - 1.35e-79  102967.893 - 1.87e-79  103865.019 - 1.15e-73
# TNe+I+G4         -51342.385  102966.769 - 1.97e-81  102976.213 - 2.91e-81  103867.091 - 4.08e-74
# TIM3e+G4         -51343.427  102968.855 - 6.95e-82  102978.299 - 1.03e-81  103869.177 - 1.44e-74
# TIM3e+I+G4       -51342.302  102968.605 - 7.88e-82  102978.185 - 1.09e-81  103875.312 - 6.69e-76
# K3P+G4           -51391.942  103063.885 - 1.61e-102  103073.194 - 2.54e-102  103957.821 -  8.1e-94
# K2P+G4           -51397.134  103072.269 - 2.43e-104  103081.444 - 4.11e-104  103959.820 - 2.98e-94
# K3P+I+G4         -51391.750  103065.501 - 7.17e-103  103074.945 - 1.06e-102  103965.823 - 1.48e-95
# K2P+I+G4         -51396.986  103073.973 - 1.04e-104  103083.282 - 1.64e-104  103967.909 - 5.22e-96
# GTR+F+R2         -51594.916  103483.831 - 1.04e-193  103494.108 - 1.01e-193  104422.464 - 1.03e-194
# F81+F+G4         -52471.850  105225.701 -        0  105235.145 -        0  106126.023 -        0
# F81+F+I+G4       -52472.043  105228.085 -        0  105237.666 -        0  106134.792 -        0
# JC+G4            -52517.850  105311.700 -        0  105320.742 -        0  106192.866 -        0
# JC+I+G4          -52517.886  105313.772 -        0  105322.947 -        0  106201.323 -        0
# GTR+F+I          -53099.287  106490.574 -        0  106500.710 -        0  107422.822 -        0
# GTR+F            -54547.995  109385.990 -        0  109395.985 -        0  110311.853 -        0
#
# AIC, w-AIC   : Akaike information criterion scores and weights.
# AICc, w-AICc : Corrected AIC scores and weights.
# BIC, w-BIC   : Bayesian information criterion scores and weights.
#
# Plus signs denote the 95% confidence sets.
# Minus signs denote significant exclusion.
#
# SUBSTITUTION PROCESS
# --------------------
#
# Model of substitution: GTR+F+G4
#
# Rate parameter R:
#
#   A-C: 2.2469
#   A-G: 4.7545
#   A-T: 1.8771
#   C-G: 1.5429
#   C-T: 8.2516
#   G-T: 1.0000
#
# State frequencies: (empirical counts from alignment)
#
#   pi(A) = 0.2806
#   pi(C) = 0.2159
#   pi(G) = 0.235
#   pi(T) = 0.2685
#
# Rate matrix Q:
#
#   A   -0.8698    0.2004    0.4614    0.2081
#   C    0.2604    -1.325    0.1497    0.9148
#   G    0.5509    0.1376   -0.7994    0.1109
#   T    0.2175    0.7358   0.09704     -1.05
#
# Model of rate heterogeneity: Gamma with 4 categories
# Gamma shape alpha: 0.5294
#
#  Category  Relative_rate  Proportion
#   1         0.03896        0.25
#   2         0.2707         0.25
#   3         0.8405         0.25
#   4         2.85           0.25
# Relative rates are computed as MEAN of the portion of the Gamma distribution falling in the category.
#
# MAXIMUM LIKELIHOOD TREE
# -----------------------
#
# Log-likelihood of the tree: -51148.3344 (s.e. 676.2595)
# Unconstrained log-likelihood (without tree): -31957.5036
# Number of free parameters (#branches + #model parameters): 146
# Akaike information criterion (AIC) score: 102588.6688
# Corrected Akaike information criterion (AICc) score: 102598.8044
# Bayesian information criterion (BIC) score: 103520.9169
#
# Total tree length (sum of branch lengths): 20.7530
# Sum of internal branch lengths: 4.5445 (21.8980% of tree length)
#
# WARNING: 10 near-zero internal branches (<0.0002) should be treated with caution
#          Such branches are denoted by '**' in the figure below
#
# NOTE: Tree is UNROOTED although outgroup taxon 'Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686' is drawn at root
#
# +--Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686
# |
# |                                               +**Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847
# |                                            +--|
# |                                            |  |  +--Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850
# |                                            |  +**|
# |                                            |     |  +**Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851
# |                                            |     +--|
# |                                            |        +**Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853
# |                                         +--|
# |                                         |  |  +**Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848
# |                                         |  +--|
# |                                         |     |  +**Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852
# |                                         |     +--|
# |                                         |        +**Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854
# |                                      +**|
# |                                      |  +**Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849
# |                                   +--|
# |                                   |  |  +--Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855
# |                                   |  +**|
# |                                   |     +------------------------------------------------Tfemoratus2_4327769.g89
# |                                +--|
# |                                |  |                 +--Tannulatus1_2465216.g23
# |                                |  |              +**|
# |                                |  |              |  +--Tpilosus2_4819112.g7
# |                                |  |           +**|
# |                                |  |           |  +**Tannulatus2_5311409.g40
# |                                |  |        +--|
# |                                |  |        |  +**Tpilosus1_4271307.g61
# |                                |  |     +--|
# |                                |  |     |  +--Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1
# |                                |  |  +--|
# |                                |  |  |  |  +--Tfemoratus1_3077924.g10
# |                                |  |  |  +--|
# |                                |  |  |     +--Tfemoratus2_3114834.g47
# |                                |  +--|
# |                                |     |  +--Tdiscoideus1_1854031.g58
# |                                |     +--|
# |                                |        |  +--Tdiscoideus2_2890578.g52
# |                                |        +--|
# |                                |           +--Tskillmani1_13332957.g20
# |                             +--|
# |                             |  |     +--Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311
# |                             |  |  +--|
# |                             |  |  |  |     +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312
# |                             |  |  |  |  +--|
# |                             |  |  |  |  |  |  +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315
# |                             |  |  |  |  |  +**|
# |                             |  |  |  |  |     |  +--Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316
# |                             |  |  |  |  |     +--|
# |                             |  |  |  |  |        |  +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317
# |                             |  |  |  |  |        +--|
# |                             |  |  |  |  |           +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319
# |                             |  |  |  +--|
# |                             |  |  |     |  +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313
# |                             |  |  |     +--|
# |                             |  |  |        |  +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318
# |                             |  |  |        +--|
# |                             |  |  |           +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320
# |                             |  +--|
# |                             |     |  +**Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314
# |                             |     +**|
# |                             |        +--Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321
# |                          +--|
# |                          |  +--Dplexippus_DPOGS214640-TA
# |                       +--|
# |                       |  +--Clectularius_CLEC006776-RA
# |                    +--|
# |                    |  +--Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820
# |                 +--|
# |                 |  |  +--Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747
# |                 |  +--|
# |                 |     +**Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748
# |              +--|
# |              |  |  +--Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739
# |              |  +--|
# |              |     +--Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087
# |           +--|
# |           |  +---Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829
# |        +--|
# |        |  |        +--Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588
# |        |  |     +--|
# |        |  |     |  |                    +--Tannulatus1_5852914.g76
# |        |  |     |  |                 +**|
# |        |  |     |  |                 |  +--Tannulatus2_6685946.g8
# |        |  |     |  |              +--|
# |        |  |     |  |              |  |  +**Tpilosus1_5418222.g21
# |        |  |     |  |              |  +**|
# |        |  |     |  |              |     +--Tpilosus2_7357420.g51
# |        |  |     |  |           +--|
# |        |  |     |  |           |  +--Tpilosus1_5497471.g120
# |        |  |     |  |        +--|
# |        |  |     |  |        |  |     +--Tdiscoideus1_6770603.g14
# |        |  |     |  |        |  |  +--|
# |        |  |     |  |        |  |  |  +--Tdiscoideus2_3746555.g55
# |        |  |     |  |        |  +--|
# |        |  |     |  |        |     +--Tskillmani1_12903966.g5
# |        |  |     |  |     +--|
# |        |  |     |  |     |  |  +--Tfemoratus1_9193525.g41
# |        |  |     |  |     |  +--|
# |        |  |     |  |     |     +**Tfemoratus2_584367.g107
# |        |  |     |  |  +--|
# |        |  |     |  |  |  +--Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1
# |        |  |     |  +--|
# |        |  |     |     +--Tdiscoideus2_3689124.g70
# |        |  |  +--|
# |        |  |  |  |      +**Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258
# |        |  |  |  |   +**|
# |        |  |  |  |   |  +**Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259
# |        |  |  |  +---|
# |        |  |  |      +**Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260
# |        |  +--|
# |        |     +--------Dplexippus_DPOGS211186-TA
# |     +--|
# |     |  +-------Dplexippus_DPOGS213623-TA
# |  +--|
# |  |  |  +**Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417
# |  |  +--|
# |  |     +**Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418
# +--|
# |  +--Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419
# |
# |        +--Tannulatus2_6776066.g34
# |     +--|
# |     |  |  +--Tpilosus1_2065760.g33
# |     |  +--|
# |     |     +--Tpilosus2_4168272.g56
# |  +--|
# |  |  |     +**Tfemoratus1_9243440.g114
# |  |  |  +--|
# |  |  |  |  +--Tfemoratus2_8651013.g277
# |  |  +--|
# |  |     +--Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1
# +--|
#    |     +--Tdiscoideus1_5565729.g65
#    |  +--|
#    |  |  +--Tskillmani1_13290908.g54
#    +--|
#       +--Tdiscoideus2_4198478.g3
#
# Tree in newick format:
#
# (Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686:0.1275601792,((((((((((((((((Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847:0.0000028573,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850:0.0024603637,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851:0.0000010000,Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853:0.0000010000):0.0010171896):0.0000021655):0.0042687197,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848:0.0000022748,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852:0.0000010000,Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854:0.0000010000):0.0010176657):0.0050679461):0.0062751523,Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849:0.0000021500):0.0000020568,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855:0.0017597029,Tfemoratus2_4327769.g89:8.9921462315):0.0000027158):0.0870280788,((((((Tannulatus1_2465216.g23:0.0005291897,Tpilosus2_4819112.g7:0.0015910004):0.0000010000,Tannulatus2_5311409.g40:0.0000010000):0.0000025151,Tpilosus1_4271307.g61:0.0000010000):0.0072414759,Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1:0.0036567268):0.0013181572,(Tfemoratus1_3077924.g10:0.0053785746,Tfemoratus2_3114834.g47:0.0024363600):0.0018717692):0.0243501015,(Tdiscoideus1_1854031.g58:0.0141876046,(Tdiscoideus2_2890578.g52:0.0059491282,Tskillmani1_13332957.g20:0.0057435277):0.0048371994):0.0111138653):0.1082001678):0.0766498397,((Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311:0.0035060273,((Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312:0.0000010000,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315:0.0000010000,(Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316:0.0030252958,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317:0.0000010000,Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319:0.0000010000):0.0006975279):0.0013228287):0.0000022051):0.0042260421,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313:0.0000010000,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318:0.0000010000,Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320:0.0000010000):0.0009922763):0.0037656201):0.0039853563):0.0064064045,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314:0.0000010000,Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321:0.0006852360):0.0000022955):0.1752761772):0.0931210715,Dplexippus_DPOGS214640-TA:0.1985516307):0.1718005328,Clectularius_CLEC006776-RA:0.1443423666):0.0840303375,Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820:0.1984019414):0.0314488098,(Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747:0.0135394329,Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748:0.0000028839):0.1740635664):0.0231541786,(Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739:0.0679149817,Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087:0.1738848130):0.0762696332):0.1144920672,Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829:0.7395205279):0.2258257025,(((Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588:0.2699787781,(((((((Tannulatus1_5852914.g76:0.0008657984,Tannulatus2_6685946.g8:0.0009561822):0.0000439592,(Tpilosus1_5418222.g21:0.0000010000,Tpilosus2_7357420.g51:0.0015588963):0.0000028810):0.0024434232,Tpilosus1_5497471.g120:0.0049019993):0.0046712810,((Tdiscoideus1_6770603.g14:0.0105594552,Tdiscoideus2_3746555.g55:0.0211699570):0.0078648581,Tskillmani1_12903966.g5:0.0094170437):0.0879417290):0.0024102976,(Tfemoratus1_9193525.g41:0.0021757690,Tfemoratus2_584367.g107:0.0000020380):0.0132639260):0.0079026536,Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1:0.0154858420):0.0311398925,Tdiscoideus2_3689124.g70:0.0297262895):0.1916070977):0.6439215593,((Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258:0.0000010000,Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259:0.0000010000):0.0000010000,Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260:0.0000010000):0.8489663851):0.3713092826,Dplexippus_DPOGS211186-TA:1.7336836193):0.4425383801):0.2418523214,Dplexippus_DPOGS213623-TA:1.5082428180):0.3476946727,(Tcastaneum_lcl|NC_007417.3_cd ...
#
# TIME STAMP
# ----------
#
# Date and time: Sun May  9 18:05:29 2021
# Total CPU time used: 157.679 seconds (0h:2m:37s)
# Total wall-clock time used: 162.383 seconds (0h:2m:42s)

# %% [markdown]
# Looks like GTR+F+G4 is the best-fit model. Now let's look at the tree:

# %%
# !cat ATPase_subunit_alpha.filtered.mafft.fasta.treefile.nwk
# Out:
# (Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686:0.1275601792,((((((((((((((((Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847:0.0000028573,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850:0.0024603637,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851:0.0000010000,Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853:0.0000010000):0.0010171896):0.0000021655):0.0042687197,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848:0.0000022748,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852:0.0000010000,Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854:0.0000010000):0.0010176657):0.0050679461):0.0062751523,Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849:0.0000021500):0.0000020568,(Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855:0.0017597029,Tfemoratus2_4327769.g89:8.9921462315):0.0000027158):0.0870280788,((((((Tannulatus1_2465216.g23:0.0005291897,Tpilosus2_4819112.g7:0.0015910004):0.0000010000,Tannulatus2_5311409.g40:0.0000010000):0.0000025151,Tpilosus1_4271307.g61:0.0000010000):0.0072414759,Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1:0.0036567268):0.0013181572,(Tfemoratus1_3077924.g10:0.0053785746,Tfemoratus2_3114834.g47:0.0024363600):0.0018717692):0.0243501015,(Tdiscoideus1_1854031.g58:0.0141876046,(Tdiscoideus2_2890578.g52:0.0059491282,Tskillmani1_13332957.g20:0.0057435277):0.0048371994):0.0111138653):0.1082001678):0.0766498397,((Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311:0.0035060273,((Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312:0.0000010000,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315:0.0000010000,(Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316:0.0030252958,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317:0.0000010000,Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319:0.0000010000):0.0006975279):0.0013228287):0.0000022051):0.0042260421,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313:0.0000010000,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318:0.0000010000,Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320:0.0000010000):0.0009922763):0.0037656201):0.0039853563):0.0064064045,(Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314:0.0000010000,Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321:0.0006852360):0.0000022955):0.1752761772):0.0931210715,Dplexippus_DPOGS214640-TA:0.1985516307):0.1718005328,Clectularius_CLEC006776-RA:0.1443423666):0.0840303375,Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820:0.1984019414):0.0314488098,(Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747:0.0135394329,Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748:0.0000028839):0.1740635664):0.0231541786,(Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739:0.0679149817,Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087:0.1738848130):0.0762696332):0.1144920672,Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829:0.7395205279):0.2258257025,(((Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588:0.2699787781,(((((((Tannulatus1_5852914.g76:0.0008657984,Tannulatus2_6685946.g8:0.0009561822):0.0000439592,(Tpilosus1_5418222.g21:0.0000010000,Tpilosus2_7357420.g51:0.0015588963):0.0000028810):0.0024434232,Tpilosus1_5497471.g120:0.0049019993):0.0046712810,((Tdiscoideus1_6770603.g14:0.0105594552,Tdiscoideus2_3746555.g55:0.0211699570):0.0078648581,Tskillmani1_12903966.g5:0.0094170437):0.0879417290):0.0024102976,(Tfemoratus1_9193525.g41:0.0021757690,Tfemoratus2_584367.g107:0.0000020380):0.0132639260):0.0079026536,Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1:0.0154858420):0.0311398925,Tdiscoideus2_3689124.g70:0.0297262895):0.1916070977):0.6439215593,((Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258:0.0000010000,Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259:0.0000010000):0.0000010000,Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260:0.0000010000):0.8489663851):0.3713092826,Dplexippus_DPOGS211186-TA:1.7336836193):0.4425383801):0.2418523214,Dplexippus_DPOGS213623-TA:1.5082428180):0.3476946727,(Tcastaneum_lcl|NC_007417.3_cd ...

# %% [markdown]
# Looks good but not very useful to see the topology. The next thing to do is use ete to visualize the tree.

# %% [markdown]
# ### Visualize the gene tree
#
# We'll use ete to see the tree.

# %%
# Create a variable for the gene tree generated with IQTREE
tree_file = "ATPase_subunit_alpha.filtered.mafft.fasta.treefile.nwk"

# Assign the tree to the variable iqtree
iqtree = Tree(tree_file)

# %% [markdown]
# Let's take a look at the tree:

# %%
print(iqtree)
# Out:
#    /-Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686
#   |
#   |                                                /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847
#   |                                             /-|
#   |                                            |  |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850
#   |                                            |   \-|
#   |                                            |     |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851
#   |                                          /-|      \-|
#   |                                         |  |         \-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853
#   |                                         |  |
#   |                                         |  |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848
#   |                                       /-|   \-|
#   |                                      |  |     |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852
#   |                                      |  |      \-|
#   |                                      |  |         \-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854
#   |                                    /-|  |
#   |                                   |  |   \-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849
#   |                                   |  |
#   |                                   |  |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855
#   |                                   |   \-|
#   |                                   |      \-Tfemoratus2_4327769.g89
#   |                                   |
#   |                                   |                  /-Tannulatus1_2465216.g23
#   |                                   |               /-|
#   |                                 /-|            /-|   \-Tpilosus2_4819112.g7
#   |                                |  |           |  |
#   |                                |  |         /-|   \-Tannulatus2_5311409.g40
#   |                                |  |        |  |
#   |                                |  |      /-|   \-Tpilosus1_4271307.g61
#   |                                |  |     |  |
#   |                                |  |   /-|   \-Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1
#   |                                |  |  |  |
#   |                                |  |  |  |   /-Tfemoratus1_3077924.g10
#   |                                |   \-|   \-|
#   |                                |     |      \-Tfemoratus2_3114834.g47
#   |                                |     |
#   |                                |     |   /-Tdiscoideus1_1854031.g58
#   |                                |      \-|
#   |                              /-|        |   /-Tdiscoideus2_2890578.g52
#   |                             |  |         \-|
#   |                             |  |            \-Tskillmani1_13332957.g20
#   |                             |  |
#   |                             |  |      /-Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311
#   |                             |  |     |
#   |                             |  |     |      /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312
#   |                             |  |     |   /-|
#   |                             |  |   /-|  |  |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315
#   |                             |  |  |  |  |   \-|
#   |                             |  |  |  |  |     |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316
#   |                             |  |  |  |  |      \-|
#   |                             |  |  |   \-|        |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317
#   |                           /-|  |  |     |         \-|
#   |                          |  |  |  |     |            \-Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319
#   |                          |  |   \-|     |
#   |                          |  |     |     |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313
#   |                          |  |     |      \-|
#   |                          |  |     |        |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318
#   |                          |  |     |         \-|
#   |                        /-|  |     |            \-Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320
#   |                       |  |  |     |
#   |                       |  |  |     |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314
#   |                       |  |  |      \-|
#   |                       |  |  |         \-Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321
#   |                     /-|  |  |
#   |                    |  |  |   \-Dplexippus_DPOGS214640-TA
# --|                    |  |  |
#   |                    |  |   \-Clectularius_CLEC006776-RA
#   |                  /-|  |
#   |                 |  |   \-Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820
#   |                 |  |
#   |                 |  |   /-Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747
#   |               /-|   \-|
#   |              |  |      \-Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748
#   |              |  |
#   |            /-|  |   /-Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739
#   |           |  |   \-|
#   |           |  |      \-Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087
#   |           |  |
#   |           |   \-Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829
#   |           |
#   |           |         /-Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588
#   |           |        |
#   |           |        |                     /-Tannulatus1_5852914.g76
#   |           |        |                  /-|
#   |           |        |                 |   \-Tannulatus2_6685946.g8
#   |           |        |               /-|
#   |           |        |              |  |   /-Tpilosus1_5418222.g21
#   |           |        |            /-|   \-|
#   |           |        |           |  |      \-Tpilosus2_7357420.g51
#   |         /-|        |           |  |
#   |        |  |      /-|         /-|   \-Tpilosus1_5497471.g120
#   |        |  |     |  |        |  |
#   |        |  |     |  |        |  |      /-Tdiscoideus1_6770603.g14
#   |        |  |     |  |        |  |   /-|
#   |        |  |     |  |      /-|   \-|   \-Tdiscoideus2_3746555.g55
#   |        |  |     |  |     |  |     |
#   |        |  |     |  |     |  |      \-Tskillmani1_12903966.g5
#   |        |  |     |  |     |  |
#   |        |  |     |  |   /-|  |   /-Tfemoratus1_9193525.g41
#   |        |  |   /-|  |  |  |   \-|
#   |        |  |  |  |  |  |  |      \-Tfemoratus2_584367.g107
#   |      /-|  |  |  |   \-|  |
#   |     |  |  |  |  |     |   \-Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1
#   |     |  |  |  |  |     |
#   |     |  |  |  |  |      \-Tdiscoideus2_3689124.g70
#   |     |  |   \-|  |
#   |     |  |     |  |      /-Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258
#   |     |  |     |  |   /-|
#   |     |  |     |   \-|   \-Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259
#   |   /-|  |     |     |
#   |  |  |  |     |      \-Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260
#   |  |  |  |     |
#   |  |  |  |      \-Dplexippus_DPOGS211186-TA
#   |  |  |  |
#   |--|  |   \-Dplexippus_DPOGS213623-TA
#   |  |  |
#   |  |  |   /-Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417
#   |  |   \-|
#   |  |      \-Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418
#   |  |
#   |   \-Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419
#   |
#   |         /-Tannulatus2_6776066.g34
#   |      /-|
#   |     |  |   /-Tpilosus1_2065760.g33
#   |     |   \-|
#   |   /-|      \-Tpilosus2_4168272.g56
#   |  |  |
#   |  |  |      /-Tfemoratus1_9243440.g114
#   |  |  |   /-|
#   |  |   \-|   \-Tfemoratus2_8651013.g277
#    \-|     |
#      |      \-Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1
#      |
#      |      /-Tdiscoideus1_5565729.g65
#      |   /-|
#       \-|   \-Tskillmani1_13290908.g54
#         |
#          \-Tdiscoideus2_4198478.g3

# %% [markdown]
# So far the tree is unrooted. Let's root the tree to one of the sequences of *Danaus plexippus*, the monarch butterfly:

# %%
# Define a variable called Dplexippus

Dplexippus = "Dplexippus_DPOGS213623-TA"

# Define Dplexippus as the root of the tree
iqtree.set_outgroup(Dplexippus)
print(iqtree)
# Out:
#    /-Dplexippus_DPOGS213623-TA
#   |
#   |                                          /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847
#   |                                       /-|
#   |                                      |  |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850
#   |                                      |   \-|
#   |                                      |     |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851
#   |                                    /-|      \-|
#   |                                   |  |         \-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853
#   |                                   |  |
#   |                                   |  |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848
#   |                                 /-|   \-|
#   |                                |  |     |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852
#   |                                |  |      \-|
#   |                                |  |         \-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854
#   |                              /-|  |
#   |                             |  |   \-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849
#   |                             |  |
#   |                             |  |   /-Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855
#   |                             |   \-|
#   |                             |      \-Tfemoratus2_4327769.g89
#   |                             |
#   |                             |                  /-Tannulatus1_2465216.g23
#   |                             |               /-|
#   |                           /-|            /-|   \-Tpilosus2_4819112.g7
#   |                          |  |           |  |
#   |                          |  |         /-|   \-Tannulatus2_5311409.g40
#   |                          |  |        |  |
#   |                          |  |      /-|   \-Tpilosus1_4271307.g61
#   |                          |  |     |  |
#   |                          |  |   /-|   \-Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1
#   |                          |  |  |  |
#   |                          |  |  |  |   /-Tfemoratus1_3077924.g10
#   |                          |   \-|   \-|
#   |                          |     |      \-Tfemoratus2_3114834.g47
#   |                          |     |
#   |                          |     |   /-Tdiscoideus1_1854031.g58
#   |                          |      \-|
#   |                        /-|        |   /-Tdiscoideus2_2890578.g52
#   |                       |  |         \-|
#   |                       |  |            \-Tskillmani1_13332957.g20
#   |                       |  |
#   |                       |  |      /-Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311
#   |                       |  |     |
#   |                       |  |     |      /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312
#   |                       |  |     |   /-|
#   |                       |  |   /-|  |  |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315
#   |                       |  |  |  |  |   \-|
#   |                       |  |  |  |  |     |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316
#   |                       |  |  |  |  |      \-|
#   |                       |  |  |   \-|        |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317
# --|                     /-|  |  |     |         \-|
#   |                    |  |  |  |     |            \-Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319
#   |                    |  |   \-|     |
#   |                    |  |     |     |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313
#   |                    |  |     |      \-|
#   |                    |  |     |        |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318
#   |                    |  |     |         \-|
#   |                  /-|  |     |            \-Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320
#   |                 |  |  |     |
#   |                 |  |  |     |   /-Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314
#   |                 |  |  |      \-|
#   |                 |  |  |         \-Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321
#   |               /-|  |  |
#   |              |  |  |   \-Dplexippus_DPOGS214640-TA
#   |              |  |  |
#   |              |  |   \-Clectularius_CLEC006776-RA
#   |            /-|  |
#   |           |  |   \-Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820
#   |           |  |
#   |           |  |   /-Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747
#   |         /-|   \-|
#   |        |  |      \-Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748
#   |        |  |
#   |      /-|  |   /-Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739
#   |     |  |   \-|
#   |     |  |      \-Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087
#   |     |  |
#   |     |   \-Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829
#   |     |
#   |     |         /-Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588
#   |     |        |
#   |     |        |                     /-Tannulatus1_5852914.g76
#   |     |        |                  /-|
#   |     |        |                 |   \-Tannulatus2_6685946.g8
#   |     |        |               /-|
#   |     |        |              |  |   /-Tpilosus1_5418222.g21
#   |     |        |            /-|   \-|
#   |     |        |           |  |      \-Tpilosus2_7357420.g51
#   |   /-|        |           |  |
#   |  |  |      /-|         /-|   \-Tpilosus1_5497471.g120
#   |  |  |     |  |        |  |
#   |  |  |     |  |        |  |      /-Tdiscoideus1_6770603.g14
#   |  |  |     |  |        |  |   /-|
#   |  |  |     |  |      /-|   \-|   \-Tdiscoideus2_3746555.g55
#   |  |  |     |  |     |  |     |
#   |  |  |     |  |     |  |      \-Tskillmani1_12903966.g5
#   |  |  |     |  |     |  |
#   |  |  |     |  |   /-|  |   /-Tfemoratus1_9193525.g41
#   |  |  |   /-|  |  |  |   \-|
#   |  |  |  |  |  |  |  |      \-Tfemoratus2_584367.g107
#   |  |  |  |  |   \-|  |
#   |  |  |  |  |     |   \-Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1
#    \-|  |  |  |     |
#      |  |  |  |      \-Tdiscoideus2_3689124.g70
#      |   \-|  |
#      |     |  |      /-Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258
#      |     |  |   /-|
#      |     |   \-|   \-Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259
#      |     |     |
#      |     |      \-Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260
#      |     |
#      |      \-Dplexippus_DPOGS211186-TA
#      |
#      |      /-Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417
#      |   /-|
#      |  |   \-Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418
#      |  |
#       \-|   /-Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419
#         |  |
#         |  |   /-Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686
#          \-|  |
#            |  |         /-Tannulatus2_6776066.g34
#            |  |      /-|
#            |  |     |  |   /-Tpilosus1_2065760.g33
#             \-|     |   \-|
#               |   /-|      \-Tpilosus2_4168272.g56
#               |  |  |
#               |  |  |      /-Tfemoratus1_9243440.g114
#               |  |  |   /-|
#               |  |   \-|   \-Tfemoratus2_8651013.g277
#                \-|     |
#                  |      \-Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1
#                  |
#                  |      /-Tdiscoideus1_5565729.g65
#                  |   /-|
#                   \-|   \-Tskillmani1_13290908.g54
#                     |
#                      \-Tdiscoideus2_4198478.g3

# %% [markdown]
# ### Create a nice-looking figure

# %% [markdown]
# We can get an idea of the topology by looking at the visualization created in the previous step. So far we see that some of the sequences are grouped by species, but there are others - especially in the genus *Tetraopes* (identifiable by a "T" before the species name) - where it would be interesting to take a closer look. To better visualize the topology we will color the tips (or leaves) according to their genus.
#
# First let's print the leaf names:

# %%
for leaf in iqtree:
    print(leaf.name)
# Out:
# Dplexippus_DPOGS213623-TA
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855
# Tfemoratus2_4327769.g89
# Tannulatus1_2465216.g23
# Tpilosus2_4819112.g7
# Tannulatus2_5311409.g40
# Tpilosus1_4271307.g61
# Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1
# Tfemoratus1_3077924.g10
# Tfemoratus2_3114834.g47
# Tdiscoideus1_1854031.g58
# Tdiscoideus2_2890578.g52
# Tskillmani1_13332957.g20
# Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315
# Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321
# Dplexippus_DPOGS214640-TA
# Clectularius_CLEC006776-RA
# Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820
# Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747
# Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748
# Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739
# Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087
# Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829
# Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588
# Tannulatus1_5852914.g76
# Tannulatus2_6685946.g8
# Tpilosus1_5418222.g21
# Tpilosus2_7357420.g51
# Tpilosus1_5497471.g120
# Tdiscoideus1_6770603.g14
# Tdiscoideus2_3746555.g55
# Tskillmani1_12903966.g5
# Tfemoratus1_9193525.g41
# Tfemoratus2_584367.g107
# Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1
# Tdiscoideus2_3689124.g70
# Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258
# Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259
# Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260
# Dplexippus_DPOGS211186-TA
# Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417
# Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418
# Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419
# Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686
# Tannulatus2_6776066.g34
# Tpilosus1_2065760.g33
# Tpilosus2_4168272.g56
# Tfemoratus1_9243440.g114
# Tfemoratus2_8651013.g277
# Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1
# Tdiscoideus1_5565729.g65
# Tskillmani1_13290908.g54
# Tdiscoideus2_4198478.g3

# %% [markdown]
# Now we need to assign each species to a subgroup. We will create a dictionary where each leaf.name will be a key and the genus name will be its value:

# %%
# Create an empty dictionary called insect_group
insect_group = {}

# For each leave in the tree
for leaf in iqtree:
    # Evaluate its name
    if "Aglabripennis" in leaf.name:
    # and create a new set of key:value pair if it coitains the name of the genus
      insect_group[leaf.name] = 'Aglabripennis'
    elif "Tcastaneum" in leaf.name:
      insect_group[leaf.name] = 'Tcastaneum'
    elif "Dplexippus" in leaf.name:
      insect_group[leaf.name] = 'Dplexippus'
    elif "Ofasciatus" in leaf.name:
      insect_group[leaf.name] = 'Ofasciatus'
    elif "Tannulatus" in leaf.name:
      insect_group[leaf.name] = 'Tannulatus'
    elif "Tpilosus" in leaf.name:
      insect_group[leaf.name] = 'Tpilosus'
    elif "Tdiscoideus" in leaf.name:
      insect_group[leaf.name] = 'Tdiscoideus'
    elif "Tskillmani" in leaf.name:
      insect_group[leaf.name] = 'Tskillmani'
    elif "Tfemoratus" in leaf.name:
      insect_group[leaf.name] = 'Tfemoratus'
    elif "Ttetrophthalmus" in leaf.name:
      insect_group[leaf.name] = 'Ttetrophthalmus'
    elif "Clectularius" in leaf.name:
      insect_group[leaf.name] = 'Clectularius'
    else:
      break
# Print the key:value pairs  
for key, value in insect_group.items():
    print(key, ' : ', value)
# Out:
# Dplexippus_DPOGS213623-TA  :  Dplexippus
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849  :  Aglabripennis
# Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855  :  Aglabripennis
# Tfemoratus2_4327769.g89  :  Tfemoratus
# Tannulatus1_2465216.g23  :  Tannulatus
# Tpilosus2_4819112.g7  :  Tpilosus
# Tannulatus2_5311409.g40  :  Tannulatus
# Tpilosus1_4271307.g61  :  Tpilosus
# Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1  :  Ttetrophthalmus
# Tfemoratus1_3077924.g10  :  Tfemoratus
# Tfemoratus2_3114834.g47  :  Tfemoratus
# Tdiscoideus1_1854031.g58  :  Tdiscoideus
# Tdiscoideus2_2890578.g52  :  Tdiscoideus
# Tskillmani1_13332957.g20  :  Tskillmani
# Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314  :  Tcastaneum
# Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321  :  Tcastaneum
# Dplexippus_DPOGS214640-TA  :  Dplexippus
# Clectularius_CLEC006776-RA  :  Clectularius
# Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820  :  Ofasciatus
# Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747  :  Ofasciatus
# Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748  :  Ofasciatus
# Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739  :  Ofasciatus
# Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087  :  Ofasciatus
# Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829  :  Ofasciatus
# Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588  :  Aglabripennis
# Tannulatus1_5852914.g76  :  Tannulatus
# Tannulatus2_6685946.g8  :  Tannulatus
# Tpilosus1_5418222.g21  :  Tpilosus
# Tpilosus2_7357420.g51  :  Tpilosus
# Tpilosus1_5497471.g120  :  Tpilosus
# Tdiscoideus1_6770603.g14  :  Tdiscoideus
# Tdiscoideus2_3746555.g55  :  Tdiscoideus
# Tskillmani1_12903966.g5  :  Tskillmani
# Tfemoratus1_9193525.g41  :  Tfemoratus
# Tfemoratus2_584367.g107  :  Tfemoratus
# Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1  :  Ttetrophthalmus
# Tdiscoideus2_3689124.g70  :  Tdiscoideus
# Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258  :  Tcastaneum
# Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259  :  Tcastaneum
# Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260  :  Tcastaneum
# Dplexippus_DPOGS211186-TA  :  Dplexippus
# Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417  :  Tcastaneum
# Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418  :  Tcastaneum
# Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419  :  Tcastaneum
# Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686  :  Aglabripennis
# Tannulatus2_6776066.g34  :  Tannulatus
# Tpilosus1_2065760.g33  :  Tpilosus
# Tpilosus2_4168272.g56  :  Tpilosus
# Tfemoratus1_9243440.g114  :  Tfemoratus
# Tfemoratus2_8651013.g277  :  Tfemoratus
# Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1  :  Ttetrophthalmus
# Tdiscoideus1_5565729.g65  :  Tdiscoideus
# Tskillmani1_13290908.g54  :  Tskillmani

# %% [markdown]
# Result: It correctly assigned each leaf.name to the genus it corresponded.
#
# BUT after having errors when trying to do:
#
#     for leaf in iqtree:
#         leaf.insect_gropu = insect_group[leaf.name]
#
# I tried a different approach: use the output to create a dictionary by hand.

# %%
order = {
  'Dplexippus_DPOGS213623-TA'                                 :  "Dplexippus",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847'  :  "Aglabripennis",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850'  :  'Aglabripennis',
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851'  :  "Aglabripennis",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853'  :  "Aglabripennis",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848'  :  "Aglabripennis",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852'  :  "Aglabripennis",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854'  :  "Aglabripennis",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849'  :  "Aglabripennis",
  'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855'  :  "Aglabripennis",
  'Tfemoratus2_4327769.g89'                                   :  "Tfemoratus",
  'Tannulatus1_2465216.g23'                                   :  "Tannulatus",
  'Tpilosus2_4819112.g7'                                      :  "Tpilosus",
  'Tannulatus2_5311409.g40'                                   :  "Tannulatus",
  'Tpilosus1_4271307.g61'                                     :  "Tpilosus",
  'Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1'  :  "Ttetrophthalmus",
  'Tfemoratus1_3077924.g10'                                   :  "Tfemoratus",
  'Tfemoratus2_3114834.g47'                                   :  "Tfemoratus",
  'Tdiscoideus1_1854031.g58'                                  :  "Tdiscoideus",
  'Tdiscoideus2_2890578.g52'                                  :  "Tdiscoideus",
  'Tskillmani1_13332957.g20'                                  :  "Tskillmani",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321'       :  "Tcastaneum",
  'Dplexippus_DPOGS214640-TA'                                 :  "Dplexippus",
  'Clectularius_CLEC006776-RA'                                :  "Clectularius",
  'Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820'             :  "Ofasciatus",
  'Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747'             :  "Ofasciatus",
  'Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748'             :  "Ofasciatus",
  'Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739'             :  "Ofasciatus",
  'Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087'             :  "Ofasciatus",
  'Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829'             :  "Ofasciatus",
  'Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588' :  "Aglabripennis",
  'Tannulatus1_5852914.g76'                                   :  "Tannulatus",
  'Tannulatus2_6685946.g8'                                    :  "Tannulatus",
  'Tpilosus1_5418222.g21'                                     :  "Tpilosus",
  'Tpilosus2_7357420.g51'                                     :  "Tpilosus",
  'Tpilosus1_5497471.g120'                                    :  "Tpilosus",
  'Tdiscoideus1_6770603.g14'                                  :  "Tdiscoideus",
  'Tdiscoideus2_3746555.g55'                                  :  "Tdiscoideus",
  'Tskillmani1_12903966.g5'                                   :  "Tskillmani",
  'Tfemoratus1_9193525.g41'                                   : "Tfemoratus",
  'Tfemoratus2_584367.g107'                                   :  "Tfemoratus",
  'Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1'  :  "Ttetrophthalmus",
  'Tdiscoideus2_3689124.g70'                                  :  "Tdiscoideus",
  'Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258'          :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259'       :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260'       :  "Tcastaneum",
  'Dplexippus_DPOGS211186-TA'                                 :  "Dplexippus",
  'Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417'        :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418'        :  "Tcastaneum",
  'Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419'           :  "Tcastaneum",
  'Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686'  :  "Aglabripennis",
  'Tannulatus2_6776066.g34'                                   :  "Tannulatus",
  'Tpilosus1_2065760.g33'                                     :  "Tpilosus",
  'Tpilosus2_4168272.g56'                                     :  "Tpilosus",
  'Tfemoratus1_9243440.g114'                                  :  "Tfemoratus",
  'Tfemoratus2_8651013.g277'                                  :  "Tfemoratus",
  'Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1'  :  "Ttetrophthalmus",
  'Tdiscoideus1_5565729.g65'                                  :  "Tdiscoideus",
  'Tskillmani1_13290908.g54'                                  :  "Tskillmani",
}

# %% [markdown]
# I could not resolve the unhashable type: 'dict_keys' error. I convert it to a tuple but got a different error.

# %%
for leaf in iqtree:
    leaf.order = order[leaf.name]
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-324-9e7803bdadce> in <module>
#       1 for leaf in iqtree:
# ----> 2     leaf.order = order[leaf.name]
#
# TypeError: unhashable type: 'dict_keys'

# %% [markdown]
# Part of this script works fine but I do not know how to get ride of the last part:
#
#   The genera of dict_keys(['Dplexippus_DPOGS213623-TA'...

# %%
for leaf in iqtree:
    print(f"The genera of {leaf.name} is {leaf.order}")
# Out:
# The genera of Dplexippus_DPOGS213623-TA is Dplexippus
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849 is Aglabripennis
# The genera of Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855 is Aglabripennis
# The genera of Tfemoratus2_4327769.g89 is Tfemoratus
# The genera of Tannulatus1_2465216.g23 is Tannulatus
# The genera of Tpilosus2_4819112.g7 is Tpilosus
# The genera of Tannulatus2_5311409.g40 is Tannulatus
# The genera of Tpilosus1_4271307.g61 is Tpilosus
# The genera of Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1 is Ttetrophthalmus
# The genera of Tfemoratus1_3077924.g10 is Tfemoratus
# The genera of Tfemoratus2_3114834.g47 is Tfemoratus
# The genera of Tdiscoideus1_1854031.g58 is Tdiscoideus
# The genera of Tdiscoideus2_2890578.g52 is Tdiscoideus
# The genera of Tskillmani1_13332957.g20 is Tskillmani
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321 is Tcastaneum
# The genera of Dplexippus_DPOGS214640-TA is Dplexippus
# The genera of Clectularius_CLEC006776-RA is Clectularius
# The genera of Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820 is Ofasciatus
# The genera of Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747 is Ofasciatus
# The genera of Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748 is Ofasciatus
# The genera of Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739 is Ofasciatus
# The genera of Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087 is Ofasciatus
# The genera of Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829 is Ofasciatus
# The genera of Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588 is Aglabripennis
# The genera of Tannulatus1_5852914.g76 is Tannulatus
# The genera of Tannulatus2_6685946.g8 is Tannulatus
# The genera of Tpilosus1_5418222.g21 is Tpilosus
# The genera of Tpilosus2_7357420.g51 is Tpilosus
# The genera of Tpilosus1_5497471.g120 is Tpilosus
# The genera of Tdiscoideus1_6770603.g14 is Tdiscoideus
# The genera of Tdiscoideus2_3746555.g55 is Tdiscoideus
# The genera of Tskillmani1_12903966.g5 is Tskillmani
# The genera of Tfemoratus1_9193525.g41 is Tfemoratus
# The genera of Tfemoratus2_584367.g107 is Tfemoratus
# The genera of Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1 is Ttetrophthalmus
# The genera of Tdiscoideus2_3689124.g70 is Tdiscoideus
# The genera of Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260 is Tcastaneum
# The genera of Dplexippus_DPOGS211186-TA is Dplexippus
# The genera of Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418 is Tcastaneum
# The genera of Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419 is Tcastaneum
# The genera of Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686 is Aglabripennis
# The genera of Tannulatus2_6776066.g34 is Tannulatus
# The genera of Tpilosus1_2065760.g33 is Tpilosus
# The genera of Tpilosus2_4168272.g56 is Tpilosus
# The genera of Tfemoratus1_9243440.g114 is Tfemoratus
# The genera of Tfemoratus2_8651013.g277 is Tfemoratus
# The genera of Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1 is Ttetrophthalmus
# The genera of Tdiscoideus1_5565729.g65 is Tdiscoideus
# The genera of Tskillmani1_13290908.g54 is Tskillmani
# The genera of dict_keys(['Dplexippus_DPOGS213623-TA', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855', 'Tfemoratus2_4327769.g89', 'Tannulatus1_2465216.g23', 'Tpilosus2_4819112.g7', 'Tannulatus2_5311409.g40', 'Tpilosus1_4271307.g61', 'Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1', 'Tfemoratus1_3077924.g10', 'Tfemoratus2_3114834.g47', 'Tdiscoideus1_1854031.g58', 'Tdiscoideus2_2890578.g52', 'Tskillmani1_13332957.g20', 'Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196417.1_15312', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196422.1_15315', 'Tcastaneum_lcl|NC_007422.5_cds_XP_015837164.1_15316', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196420.1_15317', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196423.1_15319', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196418.1_15313', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196421.1_15318', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196424.1_15320', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196419.1_15314', 'Tcastaneum_lcl|NC_007422.5_cds_XP_008196425.1_15321', 'Dplexippus_DPOGS214640-TA', 'Clectularius_CLEC006776-RA', 'Ofasciatus_lcl|KK854249.1_cds_PTY13707.1_4820', 'Ofasciatus_lcl|KK854243.1_cds_PTY13634.1_4747', 'Ofasciatus_lcl|KK854243.1_cds_PTY13635.1_4748', 'Ofasciatus_lcl|KK854243.1_cds_PTY13626.1_4739', 'Ofasciatus_lcl|KK854697.1_cds_PTY17974.1_9087', 'Ofasciatus_lcl|KK854787.1_cds_PTY18716.1_9829', 'Aglabripennis_lcl|NW_019417389.1_cds_XP_023312013.1_17588', 'Tannulatus1_5852914.g76', 'Tannulatus2_6685946.g8', 'Tpilosus1_5418222.g21', 'Tpilosus2_7357420.g51', 'Tpilosus1_5497471.g120', 'Tdiscoideus1_6770603.g14', 'Tdiscoideus2_3746555.g55', 'Tskillmani1_12903966.g5', 'Tfemoratus1_9193525.g41', 'Tfemoratus2_584367.g107', 'Ttetrophthalmus_maker-158804-exonerate_protein2genome-gene-0.0-mRNA-1', 'Tdiscoideus2_3689124.g70', 'Tcastaneum_lcl|NC_007423.3_cds_XP_971478.1_16258', 'Tcastaneum_lcl|NC_007423.3_cds_XP_015837921.1_16259', 'Tcastaneum_lcl|NC_007423.3_cds_XP_015837922.1_16260', 'Dplexippus_DPOGS211186-TA', 'Tcastaneum_lcl|NC_007417.3_cds_XP_015840522.1_3417', 'Tcastaneum_lcl|NC_007417.3_cds_XP_008190275.2_3418', 'Tcastaneum_lcl|NC_007417.3_cds_XP_972369.1_3419', 'Aglabripennis_lcl|NW_019416354.1_cds_XP_018565491.1_5686', 'Tannulatus2_6776066.g34', 'Tpilosus1_2065760.g33', 'Tpilosus2_4168272.g56', 'Tfemoratus1_9243440.g114', 'Tfemoratus2_8651013.g277', 'Ttetrophthalmus_maker-167874-exonerate_protein2genome-gene-0.0-mRNA-1', 'Tdiscoideus1_5565729.g65', 'Tskillmani1_13290908.g54']) is ['Dplexippus_DPOGS213623-TA', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562049.1_6847', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562054.1_6850', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562052.1_6851', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562055.1_6853', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562050.1_6848', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562053.1_6852', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562056.1_6854', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562051.1_6849', 'Aglabripennis_lcl|NW_019416398.1_cds_XP_018562057.1_6855', 'Tfemoratus2_4327769.g89', 'Tannulatus1_2465216.g23', 'Tpilosus2_4819112.g7', 'Tannulatus2_5311409.g40', 'Tpilosus1_4271307.g61', 'Ttetrophthalmus_maker-163393-exonerate_protein2genome-gene-0.5-mRNA-1', 'Tfemoratus1_3077924.g10', 'Tfemoratus2_3114834.g47', 'Tdiscoideus1_1854031.g58', 'Tdiscoideus2_2890578.g52', 'Tskillmani1_13332957.g20', 'Tcastaneum_lcl|NC_007422.5_cds_XP_015837163.1_15311', 'Tcastaneum_lcl|NC_007422.5_cds_XP_00 ...
